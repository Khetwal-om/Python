# %%
class Node(object):
    def __init__(self,value):
        self.info=value
        self.link=None
        
class SingleLinkedList():
    def __init__(self):
        self.start=None
    
    
    def display(self):
        if self.start is None:
            print("List is empty")
            return
        p=self.start
        while p is not None:
            print(p.info,'   ',end='')
            p=p.link
        print()
    
    
    
    
    def create_list(self):
        n=int(input("Enter the number of elements"))
        if n==0:
            return
        for i in range(n):
            data=int(input("Enter the element"))
            list.insert_at_end(data)
            
            
            
    
    def count(self):
        flag=0
        if self.start is None:
            return flag
        p=self.start
        while p is not None:
            p=p.link
            flag=flag+1
        return flag
    
    def insert_at_end(self,data):
        temp=Node(data)
        if self.start is None:
            self.start=temp
            return
        p=self.start
        while p.link is not None:
            p=p.link
        
        p.link=temp
            
    
    
    def insert_at_beginning(self,data):
        temp=Node(data)
        temp.link=self.start
        self.start=temp
        
    def insert_after(self,x,data):
        p=self.start
        while p.link is not None:
            if p.info==x:
                break
            p=p.link
        if p is None:
            print("Not found in list")
        else:
            temp=Node(data)
            temp.link=p.link
            p.link=temp
            
    def insert_before(self,x,data):
        if x==self.start.info:
            temp=Node(data)
            temp.link=self.start
            self.start=temp
            return
        p=self.start
        while p.link is not None:
            if p.link.info==x:
                break
            p=p.link
        if p is None:
            print("No element like that")
        else:
            temp=Node(data)
            temp.link=p.link
            p.link=temp
    
    
    def insert_at_position(self,k,data):
        if k==1:
            temp=Node(data)
            temp.link=self.start
            self.start=temp
            return
        
        
        p=self.start
        i=1
        while i<k-1 and p is not None:
            i+=1
            p=p.link
            
        if p is None:
            print("Nope")
        else:
            temp=Node(data)
            temp.link=p.link
            p.link=temp


list=SingleLinkedList()
list.create_list()

while True:
    print("1. Display list")
    print("2. Count the number of nodes")
    print("3. Search for an element")
    print("4. Insert in empty list/Insert in beginning of the list")
    print("5. Insert a node at the end of the list")
    print("6. Insert a node after a specified node")
    print("7. Insert a node before a specified node")
    print("9 insertion at a position")
    option=int(input("Enter the choice"))
    
    if option==1:
        list.display()
    elif option==2:
        print(list.count())

        
    elif option==4:
        data=int(input("Enter the element to be inserted"))
        list.insert_at_beginning(data)
    elif option==5:
        data=int(input("Enter the element to be inserted"))
        list.insert_at_end(data)
    elif option==6:
        x=int(input("Enter the element after which you want to enter the new element"))
        data=int(input("Enter the element to be inserted"))
        list.insert_after(x,data)
    elif option==7:
        x=int(input("Enter the element before which you want to enter the new element"))
        data=int(input("Enter the element to be inserted"))
        list.insert_before(x,data)
    elif option==9:
        k=int(input("Enter the position"))
        data=int(input("Enter the element to be inserted"))
        list.insert_at_position(k,data)

    
    elif option==8:
        break
# Out:
# Enter the number of elements3
# Enter the element2
# Enter the element3
# Enter the element4
# 1. Display list
# 2. Count the number of nodes
# 3. Search for an element
# 4. Insert in empty list/Insert in beginning of the list
# 5. Insert a node at the end of the list
# 6. Insert a node after a specified node
# 7. Insert a node before a specified node
# 9 insertion at a position
# Enter the choice9
# Enter the position1
# Enter the element to be inserted7
# 1. Display list
# 2. Count the number of nodes
# 3. Search for an element
# 4. Insert in empty list/Insert in beginning of the list
# 5. Insert a node at the end of the list
# 6. Insert a node after a specified node
# 7. Insert a node before a specified node
# 9 insertion at a position
# Enter the choice1
# 7    2    3    4
# 1. Display list
# 2. Count the number of nodes
# 3. Search for an element
# 4. Insert in empty list/Insert in beginning of the list
# 5. Insert a node at the end of the list
# ...

# %%
class Node(object):
    def __init__(self,value):
        self.info=value
        self.link=None
        
class SingleLinkedList():
    def __init__(self):
        self.start=None
        
    def create_list(self):
        n=int(input("Enter the number of elements that you want to enter"))
        if n==0:
            return
        for i in range(n):
            data=int(input("Enter the value of the element"))
            list.insert_at_end(data)
    
    def insert_at_end(self,data):
        temp=Node(data)
        if self.start is None:
            self.start=temp
            return
        p=self.start
        while p.link is not None:
            p=p.link
        p.link=temp
        
    
    def insert_at_beginning(self,data):
        temp=Node(data)
        temp.link=self.start
        self.start=temp
    
    def display_list(self):
        if self.start is None:
            print("No element is present")
            return
        p=self.start
        while p is not None:
            print(p.info,'  ',end=' ')
            p=p.link
        print()
    
    def count_nodes(self):
        count=0
        if self.start is None:
            print("O nodes")
            return 0
        p=self.start
        while p is not None:
            p=p.link
            count+=1
            
        return count
    
    


list=SingleLinkedList()
list.create_list()

while True:
    print("1. Display list")
    print("2. Count the number of nodes")
    print("4. Insert in empty list/Insert in beginning of the list")
    print("5. Insert a node at the end of the list")
    print("6. Insert a node after a specified node")
    print("7. Leave")
    option=int(input("Enter the choice"))
    
    if option==1:
        list.display_list()
    elif option==2:
        print(list.count_nodes())
    elif option==4:
        data=int(input("Enter the element to be inserted"))
        list.insert_at_beginning(data)
    elif option==5:
        data=int(input("Enter the element to be inserted"))
        list.insert_at_end(data)
    elif option==7:
        break
# Out:
# Enter the number of elements that you want to enter4
# Enter the value of the element1
# Enter the value of the element2
# Enter the value of the element3
# Enter the value of the element4
# 1. Display list
# 2. Count the number of nodes
# 4. Insert in empty list/Insert in beginning of the list
# 5. Insert a node at the end of the list
# 6. Insert a node after a specified node
# 7. Leave
# Enter the choice4
# Enter the element to be inserted7
# 1. Display list
# 2. Count the number of nodes
# 4. Insert in empty list/Insert in beginning of the list
# 5. Insert a node at the end of the list
# 6. Insert a node after a specified node
# 7. Leave
# Enter the choice1
# 7    1    2    3    4
# 1. Display list
# 2. Count the number of nodes
# 4. Insert in empty list/Insert in beginning of the list
# 5. Insert a node at the end of the list
# 6. Insert a node after a specified node
# 7. Leave
# Enter the choice2
# 5
# 1. Display list
# 2. Count the number of nodes
# ...

# %% [markdown]
# * Deletion
#
#
# 1. If the element is to be deleted is the first one.
# ```python
# if self.start.info==x:
#     self.start=self.start.link
# ```
#
# 2. Delete last node
#
# ```python
# if self.start is None:
#     return
# if self.start.info==x:
#     self.start=self.start.link
# p=self.start
# while p.link.link is not None:
#     p=p.link
# p.link=None
# ```
#
# 3. Delete Node
#
# ```python
# if self.start is None:
#     return
# if self.start.info==x:
#     self.start=self.start.link
#     return
# p=self.start
# while p.link is not None:
#     if p.link.info==x:
#         break
#     p=p.link
#
# if p.link is None:
#     print("Nothing")
# else:
#     p.link=p.link.link
#
# ```

# %% [markdown]
# ## Doubly linked list

# %%
class Node(object):
    
    def __init__(self,value):
        self.info=value
        self.next=None
        self.prev=None
    
class DoubleLinkedList(object):
    def __init__(self):
        self.start=None
        
    def create_list(self):
        n=int(input("Enter the number of elements that you want to enter"))
        if n==0:
            return
        data=int(input("Enter the first element to be inserted"))
        self.insert_in_empty_list(data)
        for i in range(n-1):
            data=int(input("Enter the next element to be inserted"))
            self.insert_in_end(data)
        
    def display_list(self):
        if self.start is None:
            print("There are no elements ")
            return
        p=self.start
        while p is not None:
            print(p.info,'   ',end=' ')
            p=p.next
            
    def insert_in_empty_list(self,data):
        temp=Node(data)
        self.start=temp
    
            
    def insert_in_beginning(self,data):
        temp=Node(data)
        temp.next=self.start
        self.start.prev=temp
        self.start=temp
            
    def insert_in_end(self,data):
        temp=Node(data)
        p=self.start
        while p.next is not None:
            p=p.next
        p.next=temp
        temp.prev=p
        
        
    def insert_after(self,data,x):
        temp=Node(data)
        
        p=self.start
        while p.next is not None:
            if p.info==x:
                break
            p=p.next
            
        if p is None:
            print("No element is present as such...")
        else:
            temp.prev=p
            temp.next=p.next
            if p.next is not None:
                p.next.prev=temp
            p.next=temp
    
    def insert_before(self,data,x):
        if self.start is None:
            print("List is empty")
            return
        if self.start.info==x:
            temp=Node(data)
            temp.next=self.start
            self.start.prev=temp
            self.start=temp
            return
        
        p=self.start
        while p is not None:
            if p.info==x:
                break
            p=p.next
            
        if p is None:
            print(x,':  element is not present in the list')
        else:
            temp=Node(data)
            temp.prev=p.prev
            temp.next=p
            p.prev.next=temp
            p.prev=temp
            
            
    
    
    

list=DoubleLinkedList()
list.create_list()
    
    
while True:
        print("1. Display list")
        print("2. Insert in empty list")
        print("3. Insert a node in the beginning of the list")
        print("4. Insert a node at the end of the list")
        print("5. Insert a node after a specified node")
        print("6. Insert a node before a specified node")
        print("7. Delete first node")
        print("8. Delete last node")
        print("9. Delete any node")
        print("10.Reverse the list")
        print("11. Quit")
        
        
        option=int(input("Enter the choice"))
        
        
         
        if option==1:
            list.display_list()

        if option==2:    
            data=int(input("Enter the element to be inserted:"))
            list.isert_in_empty_list(data)
        elif option==3:
            data=int(input("Enter the element to be inserted"))
            list.insert_in_beginning(data)
        elif option==4:
            data=int(input("Enter the element to be inserted"))
            list.insert_in_end(data)
        elif option==5:
            data=int(input("Enter the element to be inserted"))
            x=int(input("Enter the element after which to insert"))
            list.insert_after(data,x)
        elif option==6:
            data=int(input("Enter the element to be inserted"))
            x=int(input("Enter the element before which to insert"))
            list.insert_before(data,x)
        elif option==7:
            list.delete_first_node()
        elif option==8:
            list.delete_last_node()
        elif option==9:
            data=int(input("Enter the element to be deleted"))
            list.delete_node(data)
        elif option==10:
            list.reverse_list()
        elif option==11:
            break
        else:
            print("Wrong option is entered")

        print()
# Out:
# Enter the number of elements that you want to enter4
# Enter the first element to be inserted1
# Enter the next element to be inserted2
# Enter the next element to be inserted3
# Enter the next element to be inserted4
# 1. Display list
# 2. Insert in empty list
# 3. Insert a node in the beginning of the list
# 4. Insert a node at the end of the list
# 5. Insert a node after a specified node
# 6. Insert a node before a specified node
# 7. Delete first node
# 8. Delete last node
# 9. Delete any node
# 10.Reverse the list
# 11. Quit
# Enter the choice1
# 1     2     3     4     Wrong option is entered
#
# 1. Display list
# 2. Insert in empty list
# 3. Insert a node in the beginning of the list
# 4. Insert a node at the end of the list
# 5. Insert a node after a specified node
# 6. Insert a node before a specified node
# 7. Delete first node
# 8. Delete last node
# 9. Delete any node
# 10.Reverse the list
# 11. Quit
# Enter the choice3
# Enter the element to be inserted7
#
# ...

# %% [markdown]
# ###
