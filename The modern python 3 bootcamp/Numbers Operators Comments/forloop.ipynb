# %%
print('kds')
# Out:
# kds

# %%
print('kdsjdf')
print('kdsjdf')
# Out:
# kdsjdf
# kdsjdf

# %%
print('kdsjdf')
print('kdsjdf')
print('kdsjdf')
# Out:
# kdsjdf
# kdsjdf
# kdsjdf

# %%
for i in range(1,1000):
    print('ksajdkf')
# Out:
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ksajdkf
# ...
